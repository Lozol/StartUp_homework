# %%
import dlib
from imutils import face_utils
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install "dlib-19.22.99-cp39-cp39-win_amd64.whl"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Processing c:\users\hewllet\pycharmprojects\homework\dlib-19.22.99-cp39-cp39-win_amd64.whl
# ...

# %%
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25855 sha256=ecd7a49667b1b547f5df06f9eda94d1aa4e6119a6155501b91b95d7cfb063452
#   Stored in directory: C:\Users\HEWLLET\AppData\Local\Temp\pip-ephem-wheel-cache-eoiiq652\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# ...

# %% [markdown]
# ## Task 1

# %%
img = cv2.imread('titanic.jpg')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (2082, 2560)

# %%
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


#side_face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_profileface.xml')
#side_faces = side_face_cascade.detectMultiScale(gray, 1.1, 5)

# %%
face = face_classifier.detectMultiScale(img, scaleFactor=1.1, minNeighbors=4, minSize=(50,50))

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0,0,255), 4)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,5))
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## Task 2

# %%
img = cv2.imread('titanic.jpg',0)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
im = np.float32(img)
gx = cv2.Sobel(im, cv2.CV_32F, 1, 0, ksize=1)
gy = cv2.Sobel(im, cv2.CV_32F, 0, 1, ksize=1)
mg, angle = cv2.cartToPolar(gx,gy, angleInDegrees=True)
plt.imshow(mg)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(img, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(img, (x, y), (x+w, y+h), (255,160,122), 3)

plt.figure(figsize=(10,6))
plt.imshow(img)
plt.show()
