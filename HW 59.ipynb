# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
img = cv2.imread("C:/Users/HEWLLET/PycharmProjects/Homework/pani.jpg",1)

# %%
plt.imshow(img)
plt.show()

# %%
img2 = cv2.imread("C:/Users/HEWLLET/PycharmProjects/Homework/image2.jpg",1)

# %%
plt.imshow(img2)
plt.show()

# %%
img_median = cv2.medianBlur(img, 5)
imshow("1", img_median)

# %%
img2_median = cv2.medianBlur(img2, 5)
imshow("1", img2_median)

# %%
img_sobel = cv2.Sobel(img, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=3)
plt.imshow(img_sobel)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img2_sobel = cv2.Sobel(img2, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)
plt.imshow(img2_sobel)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
