# %% [markdown]
# ## Homework 24

# %% [markdown]
# ## Task 1

# %% [markdown]
# #### Два економісти заповнюють документи з власними прогнозами щодо курсу певних коштовних паперів , після чого їх складають у спільну папку. Ймовірність відхилення прогнозованного значення курсу від фактичного понад допустиму похибку для першого економіста дорівнює 0,1, для другого-0,2. Перший економіст заповнив 40 документів, другий - 60. Під час перевірки навмання взятий із папки документ виявився з суттєвою похибкою. Визначити ймовірність того, що його склав перший економіст.

# %% [markdown]
# 1) з формули ймовірності вичісляємо скільки в папкі всього документів з похибкою
# перший економіст=40*01=4
# другий економіст =60*0,2=12
# всього документів хибних=12+4=16
# 2) по формілі рахуємо що це першого документ
# 4/16=0,25
# Відповідь: ймовірність що то першого економіста док з похибкою 0,25

# %% [markdown]
# ## Task  2

# %% [markdown]
# #### Є можливість вибрати спасіб виробництва і реалізації двох наборів товарів широко вжитку. За даними відділу маркетингу , яким були проведені дослідження ринку можливий прибуток від виробництва  і реалізації  Х і У наведено в таблицях. Потрібно оцінити ступінь ризику  і запропонувати рішення щодо випуску  і реалізації одного з наборів  товарів.

# %% [markdown]
# X  | 1000|1500|2000
# -- | ----|----|-----
# P  | 0.5 |0.3 |0.2

# %% [markdown]
# Y  | 1000|1500|1750
# -- | ----|----|-----
# P  | 0.4 |0.4 |0.2

# %% [markdown]
# Розв'язання.
# Оцінимо міру і ступінь ризику випуску кожного з наборів товарів.
# Якміру ризику приймемо математичне сподівання прибутку від реалізації, як
# ступінь ризику - середньоквадратичне відхилення цього параметра:

# %% [markdown]
# 1) Рахуємо матиматичне сподівання для двох наборів товарів
# М(х)=1000*0,5+1500*0,3+2000*0,2=1350
# М(у)=1000*0,4+1500*0,4+1750*0,2=1350
# Таким чином, міра ризику випуску обох видів товарів однакова

# %% [markdown]
# Оцінимо тепер ступінь ризику:

# %%
root_mean_square_deviation_y = (((1000-(1000+1500+1750)/3)**2)*0.4+((1500-(1000+1500+1750)/3)**2)*0.4+((1750-(1000+1500+1750)/3)**2)*0.2)*0.5

# %%
root_mean_square_deviation_x = (((1000-1500)**2)*0.5+((1500-1500)**2)*0.3+((2000-1500)**2)*0.2)*0.5

# %%
print(root_mean_square_deviation_x, round(root_mean_square_deviation_y,2))
# Out:
# 87500.0 47222.22

# %% [markdown]
# Отже, ступінь ризику випуску другого набору товарів менше. Якщо немас
# чисто виробничих розумінь, можна зробити висновок, що випуск другого
# набору товарів супроводжується меншим ризиком.
