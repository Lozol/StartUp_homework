# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def imshow(title = "Image", image = None, size = 10):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
img = cv2.imread('Filarmoniya.jpg')
imshow("Filarmoniya", img)

# %%
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## Task 1

# %%
img_sobel_vert = cv2.Sobel(grey, ddepth=cv2.CV_32F, dx=0, dy=1, ksize=3)
img_sobel_horiz = cv2.Sobel(grey, ddepth=cv2.CV_32F, dx=1, dy=0, ksize=3)

# %%
imshow("Filarmoniya", img_sobel_vert)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imshow("Filarmoniya", img_sobel_horiz)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Task 2

# %%
canny = cv2.Canny(grey, 60, 180)

# %%
imshow("Filarmoniya", canny)

# %% [markdown]
# ## Task 3

# %%
from scipy import ndimage

# %%
roberts_cross_v = np.array( [[1, 0 ],
                             [0,-1 ]] )
  
roberts_cross_h = np.array( [[ 0, 1 ],
                             [ -1, 0 ]] )
  
img_roberts_vertical = ndimage.convolve( grey, roberts_cross_v )
img_roberts_horizontal = ndimage.convolve( grey, roberts_cross_h )
  
edged_img_roberts = np.sqrt( np.square(img_roberts_horizontal) + np.square(img_roberts_vertical))
edged_img_roberts*=255

# %%
 plt.imshow(edged_img_roberts)

# %% [markdown]
# # Task 4

# %% [markdown]
# Порівняння фільтрів зображення.
# - Собель плюси: багато інформації з прикладами і реалізацією. Підходить краще до неструктурованих зображень. Мінуси - погано працює на градієнтних зображеннях.
# - Кані не має мінусів
# - Робертс - не знашла реалізацію однією функцією,специфічний фільтр.
