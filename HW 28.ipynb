# %% [markdown]
# ## Task 1

# %% [markdown]
# Із генеральної совокупності, розподіленої за норм законом, отримано вибірку об'ємом п=20. Знайти з надійністю у=0,95 інтервальну оцінку для середнього квадратичного відхилення сигма генеральної совокупності.
# 1. Знаходимо середне значення xi=80/20=4
# 2. знаходимо середне квадратичне відхилення D=(2*(1-4)кв+3*(2-4)кв+10*(4-4)кв+3*(6-4)кв+2*(7-4)кв)/20=(18+12+0+12+18)/20=3
# сигма=1,73
# Відкоректований корінь із дисперсії для вибірки se=20/19*1,73=1,82
# 3. Знаходимо точність оцінки 1,96*1,82/4,47=0,8 де 1,96 із таблиці Лапласа для надійності 0,95
# 1,82 коректована дисперсія, 4,47 корінь з 2ю.
# Відповідь: інтервальна оцінка (4-0,8, 4+0,8)= (3,2,4,8)

# %% [markdown]
# ## Task 2

# %% [markdown]
# Знайти з надійністю у=0,95 інтервальну оцінку для ймовірності настання події А в кожному із п=100 незалежних повторних випробувань, якщо подія відбулась ь=40 раз
# 1.	Обчислим відносну частоту 40/100=0,4
# 2.	Знайдем параметр t по функції Лапласа  для надійності 0,95 = 1,96
# 3.	Точність оцінки =1,96* кв коріно 0,4*(1-04)/100=0,096
# 4.	Обчислюємо довірчий інтервал 0,4-0,096<p<0,4+0,096
# Відповідь 0,304<p<0.496

# %% [markdown]
# ## Task 3

# %% [markdown]
# Знайти мінімальний об'єм вибірки, при якому з надійністю у=0,99 точність оцінки математичного сподівання альфа нормально розподіленої ознаки дорівнює =0,6, якщо середнє квадратичне відхилення сигма = 3
#
# 1.	Знайдем параметр t по функції Лапласа  для надійності 0,99 2Ф(t) = γ,
# t = 2,58.
# 2.	Знаходимо величину об’єму вибірки по формілі
# n = 2,58²·(3²/0,6²) = 166,41.
#
# Відповідь: nmin = 166.
