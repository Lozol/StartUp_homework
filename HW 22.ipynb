# %% [markdown]
# ## Task 1

# %% [markdown]
# Вирішіть задачу: За підсумками іспитів з 37 студентів відмінну оцінку з математики мали 15 студентів, з фізики - 16, з хімії - 19, з математики та фізики - 7, з математики та хімії - 9, з фізики та хімії - 6, з усіх трьох дисциплін - 4. Скільки студентів отримали хочаб по одній відмінній оцінці?

# %% [markdown]
# 1) скільки сдуденів не отримали відмінних оцінок взагалі.
# Скористаємось методами включення виключення
# 37-15(матем)-16(фізика)-19(хімія)+7(матем+фізика)+9(матем+хімія)+6(фізика+хімія)-4(матем+фізика+хімія)=5
# 2) Всього студентів 37 мінус 5 невдах дорівнює = 32 студента отримали хоча б одну відмінну оцінку
# Відповідь: 32 студента

# %% [markdown]
# ## Task 2

# %% [markdown]
# Вирішіть задачу: Протягом 3 днів вересня було 12 дощових, 8 вітряних, 4 холодних, 5 дощових та вітряних, 3 дощовиз та холодних, 2 вітряних та холодних, а один день був дощовий вітряниій та холодний одночасно. Скільки днів у вересні була гарна погода?

# %% [markdown]
# Згідно методу включення виключення кількість днів що стояла гарна погода  вирішуємо:
# N= 30 всього днів вересня
# D=12 дощові дні
# X=4 холодних
# B=8 вітряних
# DB=5 дощові та вітряні
# DX=3 дощові та холодні
# BX=2 вітряні та холодні
# DBX=1 вітряний, дощовий та холодний
# N-D-B-X+DB+DX+BX-DBX=30-12-8-4+5+3+2-1=15
# Відповідь 15 днів
