# %% [markdown]
# ## Task 1

# %% [markdown]
# Ймовірність того, що при перевірці деталь виявиться стандартною, дорівнює 0,6. Перевірці підлягають 3 деталі. Побудувати закон розподілу системи двох випадкових величин х-появи числа бракованих деталей і у-появи числа стандартних деталей.
# Обчислити коєфіцієнт кореляції.

# %% [markdown]
# |xi|    0|    1|    2|    3|
# |--|-----|-----|-----|-----|
# |px|0.216|0.432|0.288|0.064|
# |py|0.064|0.288|0.432|0.216|

# %% [markdown]
# rxy=1

# %% [markdown]
# ## Task 2

# %% [markdown]
# Розглянемо дві умовні акції х і у. Для кожної з них за допомогою статистичних досліджень були розраховані
# відносні частоти очікуваних прибутків залежно від п'яти станів  економічного середовища: значне піднесення, незначне піднесення, стагнація, незначний спад, значний спад.
# Необхідно
# 1) обчислити очікувану норму прибутку по кожній з акції
# 2)  оцінити ступінь ризику обох акцій за допомогою середньоквадратичного відхилення;
# 3) проаналізувати наявність звязку між акціями х та у за допомогою коєфіцієнтів коваріації та кореляції.

# %% [raw]
# 1) норма прибутку Х
# 10*0,1+5*0,3=2*0,2+1*0,3+(-5)*0,1=1+1,5+0,4+0,3-0,5=2,7
# норма прибутку У
# 20*0,1+10*0,3+2*0,2+(-2)*0,3+(-8)*0,1=2+3+0,4-0,6-0,8=4

# %% [markdown]
# 2)сред квадрат выдхилення для Х
# (10-2,7)^2*0,1+(5-2,7)^2*0,3+(2-2,7)^2*0,2+(1-2,7)^2*0,3+(-5-2,7)^2*0,1=13.81 кв корень=3,72
# сред квадрат выдхилення для У
# (20-4)^2*0,1+10-4)^2*0,3+(2-4)^2*0,2+(-2-4)^2*0,3+(-8-4)^2*0,162,4 кв корень=7,9
# Відхилення по Х нижче значить ця акція привабливіша

# %% [markdown]
# 3) Коваріація для ху=(10-2,7)(20-4)+(5-2,7)(10-4)+(2-2,7)(2-4)+(1-2,7)(-2-4)+(-5-2,7)(-8-4)=234,3/3=78,2

# %% [markdown]
# кореляція 78,2/3,72*7,9=2,66
